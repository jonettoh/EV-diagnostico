# %%
import json
import pandas as pd
from pandas.io.json import json_normalize
import warnings
warnings.filterwarnings("ignore")

# %%
#Aca obtenemos los tweets
raw_tweets = pd.read_json('farmers-protest-tweets-2021-03-5.json', lines=True)
raw_tweets = raw_tweets[raw_tweets['lang']=='en']
#Aca se obtiene la informacion de los usuarios
users = json_normalize(raw_tweets['user'])
users.drop(['description', 'linkTcourl'], axis=1, inplace=True)
users.rename(columns={'id':'userId', 'url':'profileUrl'}, inplace=True)
users = pd.DataFrame(users)
users.drop_duplicates(subset=['userId'], inplace=True)
user_id = []
for user in raw_tweets['user']:
    uid = user['id']
    user_id.append(uid)
raw_tweets['userId'] = user_id
#Aca la informacion sobre los tweets
cols = ['url', 'date', 'renderedContent', 'id', 'userId', 'replyCount', 'retweetCount', 'likeCount', 'quoteCount', 'source', 'media', 'retweetedTweet', 'quotedTweet', 'mentionedUsers']
tweets = raw_tweets[cols]
tweets.rename(columns={'id':'tweetId', 'url':'tweetUrl'}, inplace=True)
tweets['date']= pd.to_datetime(tweets['date']).dt.date
users.head(5)
tweets.head(5)
# Out:
#                                             tweetUrl        date  \
# 0  https://twitter.com/ShashiRajbhar6/status/1376...  2021-03-30
# 1  https://twitter.com/kaursuk06272818/status/137...  2021-03-30
# 2  https://twitter.com/kaursuk06272818/status/137...  2021-03-30
# 3  https://twitter.com/SukhdevSingh_/status/13767...  2021-03-30
# 4  https://twitter.com/Davidmu66668113/status/137...  2021-03-30
#
#                                      renderedContent              tweetId  \
# 0                       Support 👇\n\n#FarmersProtest  1376739399593910273
# 1  Supporting farmers means supporting our countr...  1376739306287427584
# 2  Support farmers if you are related to food #St...  1376738704128020488
# 3  #StopHateAgainstFarmers support #FarmersProtes...  1376738640542400518
# 4  You hate farmers I hate you, \nif you love the...  1376738579171344386
#
#                 userId  replyCount  retweetCount  likeCount  quoteCount  \
# 0  1015969769760096256           0             0          0           0
# 1  1332937272581263362           0             0          0           0
# 2  1332937272581263362           0             0          0           0
# 3  1308356658582618112           0             1          3           0
# 4  1357311756532649985           0             0          1           0
#
#                                               source  \
# 0  <a href="http://twitter.com/download/android" ...
# 1  <a href="http://twitter.com/download/android" ...
# 2  <a href="http://twitter.com/download/android" ...
# 3  <a href="http://twitter.com/download/android" ...
# 4  <a href="http://twitter.com/download/android" ...
#
#                                                media  retweetedTweet  \
# 0                                               None             NaN
# 1  [{'previewUrl': 'https://pbs.twimg.com/media/E...             NaN
# 2  [{'previewUrl': 'https://pbs.twimg.com/media/E...             NaN
# 3                                               None             NaN
# 4                                               None             NaN
#
#   quotedTweet mentionedUsers
# 0        None           None
# 1        None           None
# 2        None           None
# 3        None           None
# 4        None           None

# %%
def top_tweets(df):
    db = df.sort_values(['replyCount'], ascending=False).groupby('tweetUrl').head(10)
    return db

# %%
def top_users(df):
    db = df.sort_values(['statusesCount'], ascending=False).groupby('username').head(10)
    return db

# %%
def top_days(df):
    db = df.groupby(['date'])['date'].count().nlargest(10)
    return db

# %%
def main(tweets,users):
    #return top_tweets(tweets)
    #return top_users(users)
    return top_days(tweets)

if "__name__" == "__main__":
    main(tweets, users)
    
main(tweets,users)
# Out:
# date
# 2021-02-03    83403
# 2021-02-04    58300
# 2021-02-05    33165
# 2021-02-02    28440
# 2021-02-06    22298
# 2021-02-07    11244
# 2021-02-09     9269
# 2021-02-08     8863
# 2021-02-10     7938
# 2021-02-11     5668
# Name: date, dtype: int64
